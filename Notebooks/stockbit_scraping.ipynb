# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from google_play_scraper import Sort, reviews_all

# %%
import numpy as np

result, continuation_token = reviews(
    'com.stockbit.android',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=1000,
    filter_score_with=None
)

df_stockbit = pd.DataFrame(np.array(result), columns=['review'])
df_stockbit = df_stockbit.join(pd.DataFrame(df_stockbit.pop('review').tolist()))

print(f'Berhasil mengambil {len(df_stockbit)} ulasan.')
display(df_stockbit[['userName', 'at', 'score', 'content']].head())
# Out:
# Total reviews scraped: 17360
#                                reviewId         userName  \
# 0  37203e73-a1a5-4898-833a-075f119b3bc0  Pengguna Google
# 1  f68eaff3-537f-4ba8-9655-f35d29f0d414  Pengguna Google
# 2  8c915af6-8cd1-455f-86ef-db3f7b440d0e  Pengguna Google
# 3  22f95729-6230-4221-a659-5d1fbade7ac6  Pengguna Google
# 4  62ebd586-605e-4c63-9684-8ed83aeda7ad  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                             mantap      5              0
# 1  Keren. Sangat membantu. Tapi sayangnya belum a...      5             11
# ...

# %%
df_stockbit.to_csv('stockbit_reviews.csv', index=False)
print('Data saved to stockbit_reviews.csv')
# Out:
# Data saved to stockbit_reviews.csv
